# %% [markdown]
# #Funtions
# 1.What is the difference between a function and a method in Python?
# -->funtion is a block of code which is reusable and not related to classes or objects.Method is also a block of code but related to the classes and objects.example:funtion:def print():
#    return "hello",method :class printing:
#       def print():
#           return "hello"
#   printing.print()
#
# 2.Explain the concept of function arguments and parameters in Python.
# -->function arguments are passed during function call example:def print(name,age):  return name,age
#      print(razia,21) here name and age are arguments,razia and 21 are the funtion arguments
#
# 3.What are the different ways to define and call a function in Python?
# -->there are differnt ways like function with parameters,without parameters,default parameters with respect to calling .
# example:parameterised funtion with funtion calling def print(name):
#   print("hello",name)
#   print("razia"),non parameterised funtion with function calling def print():
#      print("hello","razia")
# 4. What is the purpose of the `return` statement in a Python function?
# -->it return the values as it is example:if it is a string it return string but not nonetype,and if we give many values it defaultly returns the elements in the tuple.also it terminates after exectution.
#
# 5.. What are iterators in Python and how do they differ from iterables?
# -->iterable:is an object which return iterators
#
#   iterator:is an object which specifies where the current iteration is located
# 6.Explain the concept of generators in Python and how they are defined.
# -->generators are used for making the iterator it uses yield instead of return in order to generate lazily which makes easier to generate n number of elements.
# 7. What are the advantages of using generators over regular functions?
# -->there is no limit of generation of elements,faster in the time exectution.example:for fibonacci series generation if the input is given as 10000 normal funtion may slow down because it exectues in one go where as this generators exectues one by one .
# 8. What is a lambda function in Python and when is it typically used?
# -->lambda is an anonymous funtion or short hand function used when there is no name for the funtion ,used when the code to be completed in few lines.
#
# 9.Explain the purpose and usage of the `map()` function in Python
# -->purpose:using map() :we can perform operation on every element of iterables.
# usage:map() takes arguments such as funtion name and iterable name.
#
# 10.What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# -->map():perform operation on every element of a iterable.
#  reduce():perform operation and returns a value based the condition provided.
#  filter():filters elements of a iterables based on the condition.
#
# 11.Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
# -->

# %% [markdown]
# ![WhatsApp Image 2025-02-05 at 15.52.34_dce366bb.jpg](data:image/jpeg;base64,...)

# %%
#1.Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
from functools import reduce
l=list(map(int,input().split(' ')))
reduce(lambda x,y:x+y,list(filter(lambda x:x%2==0,l)))
# Out:
# 1 2 3 4 5
# 6

# %%
#2.Create a Python function that accepts a string and returns the reverse of that string
s=input()
reduce(lambda x,y:y+x,s)
# Out:
# razzi
# 'izzar'

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
l1=list(map(int,input().split(' ')))
l2=map(lambda x:x**2,l1)
print(list(l2))
# Out:
# 1 2 3 4 5
# [1, 4, 9, 16, 25]

# %%
#4.Write a Python function that checks if a given number is prime or not from 1 to 200
n=int(input())
l=lambda n:all(n%i!=0 for i in range(2,n)) and n>1
l(n)
# Out:
# 5
# True

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
n=int(input())
fib1=lambda n:n if(n<=1) else fib1(n-1)+fib1(n-2)
[fib1(i) for i in range(n)]
# Out:
# 5
# [0, 1, 1, 2, 3]

# %%
#6.Write a generator function in Python that yields the powers of 2 up to a given exponent.
n=int(input())
def pow(n):
  for i in range(n):
    yield 2**i
for i in pow(n):
  print(i)
# Out:
# 5
# 1
# 2
# 4
# 8
# 16

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a string.
str=input()
def read(str):
  for i in str:
    yield i
for i in read(str):
  print(i)
# Out:
# razia
# r
# a
# z
# i
# a

# %%
#8.Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
n = int(input("Enter number of tuples: "))
tuples_list = [tuple(map(int, input("Enter tuple: ").split())) for _ in range(n)]
sorted_list = sorted(tuples_list, key=lambda x: x[1])
print("Sorted List:", sorted_list)
# Out:
# Enter number of tuples: 2
# Enter tuple  1 4
# Enter tuple  4 2
# Sorted List: [(4, 2), (1, 4)]

# %%
#9.Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit
n=list(map(int,input().split(',')))
list(map(lambda x:x*9/5+32,n))
# Out:
# 52,30,65
# [125.6, 86.0, 149.0]

# %%
#10.. Create a Python program that uses `filter()` to remove all the vowels from a given string
str=input()
list(filter(lambda x:x not in 'aeiouAEIOU',str))
# Out:
# razia
# ['r', 'z']

# %%
"""11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:







Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
order is smaller than 100,00 €.

Write a Python program using lambda and map."""
